# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
ub = pd.read_csv("/content/drive/My Drive/colab_data/uber_dataset/datasets_1026_1855_My Uber Drives - 2016.csv")

# %%
ub.head(3)
# Out:
#       START_DATE*       END_DATE*  ... MILES*         PURPOSE*
# 0  1/1/2016 21:11  1/1/2016 21:17  ...    5.1   Meal/Entertain
# 1   1/2/2016 1:25   1/2/2016 1:37  ...    5.0              NaN
# 2  1/2/2016 20:25  1/2/2016 20:38  ...    4.8  Errand/Supplies
#
# [3 rows x 7 columns]

# %%
ub['CATEGORY*'].value_counts()
# Out:
# Business    1078
# Personal      77
# Name: CATEGORY*, dtype: int64

# %%
plt.figure(figsize=(6,4), dpi=100)
bars = plt.bar(['Business', 'Personal'],ub['CATEGORY*'].value_counts(),label = ('/','*'))
patterns = ['/','*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))
plt.xlabel('no of rides')
plt.ylabel('types of rides')
plt.title("No of Rides Category Wise")
plt.legend()
plt.show()

#plt.figure(figsize=(6,4), dpi=100)
#bars = plt.bar(labels, values)

#patterns = ['/', 'O', '*']
#for bar in bars:
    #bar.set_hatch(patterns.pop(0))


#plt.show()

# %%
ub['CATEGORY*'].unique()
# Out:
# array(['Business', 'Personal', nan], dtype=object)

# %%
ub['CATEGORY*'].unique()
# Out:
# array(['Business', 'Personal', nan], dtype=object)

# %%
ub['START*'].unique()
# Out:
# array(['Fort Pierce', 'West Palm Beach', 'Cary', 'Jamaica', 'New York',
#        'Elmhurst', 'Midtown', 'East Harlem', 'Flatiron District',
#        'Midtown East', 'Hudson Square', 'Lower Manhattan',
#        "Hell's Kitchen", 'Downtown', 'Gulfton', 'Houston', 'Eagan Park',
#        'Morrisville', 'Durham', 'Farmington Woods', 'Whitebridge',
#        'Lake Wellingborough', 'Fayetteville Street', 'Raleigh',
#        'Hazelwood', 'Fairmont', 'Meredith Townes', 'Apex', 'Chapel Hill',
#        'Northwoods', 'Edgehill Farms', 'Tanglewood', 'Preston',
#        'Eastgate', 'East Elmhurst', 'Jackson Heights', 'Long Island City',
#        'Katunayaka', 'Unknown Location', 'Colombo', 'Nugegoda',
#        'Islamabad', 'R?walpindi', 'Noorpur Shahan', 'Heritage Pines',
#        'Westpark Place', 'Waverly Place', 'Wayne Ridge', 'Weston',
#        'East Austin', 'West University', 'South Congress', 'The Drag',
#        'Congress Ave District', 'Red River District', 'Georgian Acres',
# ...

# %%
ubc = ub['START*'].unique()

# %%
c = 0
for i in ubc :
  c = c+1
print(c)
# Out:
# 178

# %%
top_places = ub['START*'].value_counts()[0:6]
top_places
# Out:
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
# Durham               37
# Name: START*, dtype: int64

# %%
plt.figure(figsize=(6,4), dpi=100)
top_places = plt.barh(['Cary','Unknown Location','Morrisville','Whitebridge','Islamabad','Durham'],ub['START*'].value_counts()[0:6])
plt.xticks(rotation='vertical')
plt.xlabel('Locations')
plt.ylabel('No of rides')
plt.title("No of rides location wise !!!")
plt.show()

# %%
print(ub.groupby('START*'))

# %%
ub['START*'].value_counts()
# Out:
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
#                    ...
# Eagle Rock            1
# Elk Park              1
# Parkwood              1
# Santa Clara           1
# Ingleside             1
# Name: START*, Length: 177, dtype: int64

# %%
ub.head()
# Out:
#       START_DATE*       END_DATE*  ... MILES*         PURPOSE*
# 0  1/1/2016 21:11  1/1/2016 21:17  ...    5.1   Meal/Entertain
# 1   1/2/2016 1:25   1/2/2016 1:37  ...    5.0              NaN
# 2  1/2/2016 20:25  1/2/2016 20:38  ...    4.8  Errand/Supplies
# 3  1/5/2016 17:31  1/5/2016 17:45  ...    4.7          Meeting
# 4  1/6/2016 14:42  1/6/2016 15:49  ...   63.7   Customer Visit
#
# [5 rows x 7 columns]

# %%
ub['MILES*'].value_counts()
# Out:
# 9.9      28
# 3.1      26
# 2.1      19
# 10.4     19
# 2.5      19
#          ..
# 11.1      1
# 10.7      1
# 195.6     1
# 16.6      1
# 22.7      1
# Name: MILES*, Length: 257, dtype: int64

# %%
ub['MILES*'].dtype
# Out:
# dtype('float64')

# %%
ub['MILES*'] = ub['MILES*'].astype('int64')

# %%
ub['MILES*'].value_counts()
# Out:
# 2     142
# 1     128
# 3     121
# 5      80
# 4      75
#      ...
# 47      1
# 46      1
# 41      1
# 39      1
# 37      1
# Name: MILES*, Length: 69, dtype: int64

# %%
ub.head()
# Out:
#       START_DATE*       END_DATE*  ... MILES*         PURPOSE*
# 0  1/1/2016 21:11  1/1/2016 21:17  ...      5   Meal/Entertain
# 1   1/2/2016 1:25   1/2/2016 1:37  ...      5              NaN
# 2  1/2/2016 20:25  1/2/2016 20:38  ...      4  Errand/Supplies
# 3  1/5/2016 17:31  1/5/2016 17:45  ...      4          Meeting
# 4  1/6/2016 14:42  1/6/2016 15:49  ...     63   Customer Visit
#
# [5 rows x 7 columns]

# %%
ub['MILES*'].value_counts()[0:15]
# Out:
# 2     142
# 1     128
# 3     121
# 5      80
# 4      75
# 6      73
# 7      64
# 8      63
# 9      61
# 10     49
# 12     39
# 0      30
# 13     29
# 11     27
# 15     20
# Name: MILES*, dtype: int64

# %%
#gk = df.groupby('Team')

# %%
ubp = ub.groupby("CATEGORY*").sum()

# %%
ubp.head()
# Out:
#            MILES*
# CATEGORY*
# Business    11001
# Personal      685

# %%
for i,x in ubp.items() :
  print(i,x)
# Out:
# MILES* CATEGORY*
# Business    11001
# Personal      685
# Name: MILES*, dtype: int64

# %%
plt.pie(ubp,autopct='%.2f %%')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **FINAL ONE **

# %%
plt.figure(figsize=(6,4),dpi=150)
my_explode = (0, 0.5)
labels = ['Business','Personal']
for i,x in ubp.items() :
  plt.pie([x],labels = labels,explode = my_explode,autopct='%.2f %%')
plt.title("Category of Rides Miles wise !!!!")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """

# %%
ubpu = ub['PURPOSE*'].value_counts()
ubpu
# Out:
# Meeting            187
# Meal/Entertain     160
# Errand/Supplies    128
# Customer Visit     101
# Temporary Site      50
# Between Offices     18
# Moving               4
# Airport/Travel       3
# Commute              1
# Charity ($)          1
# Name: PURPOSE*, dtype: int64

# %%
plt.figure(figsize=(6,4),dpi=150)
for keys , values in ubpu.items():
  plt.bar(keys,values)
  plt.xticks(rotation = 'vertical')
  plt.ylabel("No of rides")
  plt.xlabel("Types of rides ")
  plt.title("No of rides Type Wise...")

# %% [markdown]
# **FINAL ONE **

# %%
plt.figure(figsize=(6,4),dpi=150)
for keys , values in ubpu.items():
  plt.annotate(values,xy=(keys,values))
  plt.bar(keys,values)
  plt.xticks(rotation = 'vertical')
  plt.ylabel("No of rides")
  plt.xlabel("Types of rides ")
  plt.title("No of rides Type Wise...")

# %%
ub.head()
# Out:
#       START_DATE*       END_DATE*  ... MILES*         PURPOSE*
# 0  1/1/2016 21:11  1/1/2016 21:17  ...      5   Meal/Entertain
# 1   1/2/2016 1:25   1/2/2016 1:37  ...      5              NaN
# 2  1/2/2016 20:25  1/2/2016 20:38  ...      4  Errand/Supplies
# 3  1/5/2016 17:31  1/5/2016 17:45  ...      4          Meeting
# 4  1/6/2016 14:42  1/6/2016 15:49  ...     63   Customer Visit
#
# [5 rows x 7 columns]

# %%
top_places = ub['START*'].value_counts()[0:6]
top_places
# Out:
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
# Durham               37
# Name: START*, dtype: int64

# %% [markdown]
# **final**

# %%
plt.figure(figsize=(6,4),dpi=150)
for u,v in top_places.items() :
  plt.annotate(v,xy=(u,v))
  plt.bar(u,v)
  plt.xticks(rotation = 'vertical')
  plt.xlabel('Locations')
  plt.ylabel('No of rides')
  plt.title("No of rides location wise !!!")

# %% [markdown]
# **FINAL**

# %%
plt.figure(figsize=(6,4), dpi=100)
bars = plt.bar(['Business', 'Personal'],ub['CATEGORY*'].value_counts(),label = ('/','*'))
patterns = ['/','*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))
plt.xlabel('no of rides')
plt.ylabel('types of rides')
plt.title("No of Rides Category Wise")
plt.legend()
plt.show()

# %% [markdown]
# # problem statements .

# %% [markdown]
# # 1) HOW MANY TYPES OF RIDES AND HOW MUCH ??

# %% [markdown]
# # 2) HOW MANY MILES PERCENTAGE AND CATEGORY WISE ??

# %% [markdown]
# # 3) TYPE WISE RIDES ??

# %% [markdown]
# # 4) WHICH LOCATION IS MOST FAMOUS LOCATION ?

# %% [markdown]
# # 1) HOW MANY TYPES OF RIDES AND HOW MUCH ??

# %%
plt.figure(figsize=(6,4), dpi=100)
bars = plt.bar(['Business', 'Personal'],ub['CATEGORY*'].value_counts(),label = ('/','*'))
patterns = ['/','*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))
plt.xlabel('no of rides')
plt.ylabel('types of rides')
plt.title("No of Rides Category Wise")
plt.legend()
plt.show()

# %% [markdown]
# # 2) HOW MANY MILES PERCENTAGE AND CATEGORY WISE ??

# %%
plt.figure(figsize=(6,4),dpi=150)
my_explode = (0, 0.5)
labels = ['Business','Personal']
for i,x in ubp.items() :
  plt.pie([x],labels = labels,explode = my_explode,autopct='%.2f %%')
plt.title("Category of Rides Miles wise !!!!")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """

# %% [markdown]
# # 3) TYPE WISE RIDES ??

# %%
plt.figure(figsize=(6,4),dpi=150)
for keys , values in ubpu.items():
  plt.annotate(values,xy=(keys,values))
  plt.bar(keys,values)
  plt.xticks(rotation = 'vertical')
  plt.ylabel("No of rides")
  plt.xlabel("Types of rides ")
  plt.title("No of rides Type Wise...")

# %% [markdown]
# # 4) WHICH LOCATION IS MOST FAMOUS LOCATION ?

# %%
plt.figure(figsize=(6,4),dpi=150)
for u,v in top_places.items() :
  plt.annotate(v,xy=(u,v))
  plt.bar(u,v)
  plt.xticks(rotation = 'vertical')
  plt.xlabel('Locations')
  plt.ylabel('No of rides')
  plt.title("No of rides location wise !!!")
